# %%
import pandas as pd

# %%
csv_data = pd.read_csv('hbcsv.csv')

# %%
csv_data.columns
# Out:
# Index(['Brand', 'Name', 'Anchal', 'Type', 'Condition', 'Used For', 'Lot No',
#        'Price', 'Mileage', 'Engine', 'Make Year', 'Kilometers'],
#       dtype='object')

# %%
csv_data.rename(columns={'Lot No':  'Lot', 'Make Year': 'Make'})
# Out:
#           Brand      Name    Anchal      Type                  Condition  \
# 0         bajaj    pulsar   Bagmati    Sports                  Excellent
# 1         bajaj    pulsar     Koshi    Sports                        NaN
# 2         bajaj    pulsar   Bagmati  Standard                  Good/Fair
# 3       enfield   classic   Bagmati  Standard                  Excellent
# 4         bajaj   avenger   Bagmati   Cruiser                  Excellent
# 5         bajaj    pulsar   Bagmati    Sports                  Excellent
# 6       UnKnown   UnKnown   Bagmati  Standard                  Excellent
# 7        yamaha        fz   Bagmati    Sports  Like New (used few times)
# 8        suzuki    gixxer   Bagmati    Sports                  Excellent
# 9         bajaj    pulsar   Bagmati  Standard                  Good/Fair
# 10     mahindra     rodeo   Bagmati    Scooty                  Excellent
# 11        honda       cbr   Bagmati    Sports                  Excellent
# ...
