# %%
import pandas as pd

# %%
csv_data = pd.read_csv('hbcsv.csv')

# %%
csv_data.columns
# Out:
# Index(['Cost', 'Condition', 'Anchal', 'Lot No', 'Make Year', 'Kilometers'], dtype='object')

# %%
csv_data.rename(columns={'Lot No':  'Lot', 'Make Year': 'Make'})
# Out:
#          Cost  Condition    Anchal Lot  Make Kilometers
# 0      186000  Excellent   Bagmati  75  2016        22k
# 1      140000   Like New   Bagmati  75  2016      11200
# 2      144000  Excellent   Bagmati  68  2015        15k
# 3      180000  Excellent   Bagmati  72   NaN      38000
# 4       85000  Excellent   Bagmati  39  2012      49125
# 5      270000   Like New   Bagmati  93  2018       5000
# 6      125000  Excellent   Bagmati  82  2016        NaN
# 7      127000  Excellent   Bagmati  70  2015        NaN
# 8      110000  Excellent   Bagmati  57  2014      40000
# 9      235000   Like New   Bagmati  95  2018       3950
# 10     230000  Excellent   Bagmati  89  2017       9500
# 11      50000        NaN   Bagmati  35   NaN        NaN
# 12     370000  Excellent   Bagmati  72  2015      20000
# 13     265000   Like New   Bagmati  86  2018       6600
# 14     135000  Excellent   Bagmati  53   NaN        NaN
# 15     135000  Excellent   Bagmati  55   NaN        NaN
# ...
